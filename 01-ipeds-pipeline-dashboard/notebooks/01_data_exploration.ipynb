# %% [markdown]
# # 01 — IPEDS Data Exploration
#
# Initial EDA on raw IPEDS CSV files.

# %%
import polars as pl
from pathlib import Path
from src.config import RAW_DIR, SURVEY_COMPONENTS, SURVEY_YEARS

print(f"Raw data directory: {RAW_DIR}")
print(f"Components: {SURVEY_COMPONENTS}")
print(f"Years: {SURVEY_YEARS}")

# %% [markdown]
# ## File Discovery

# %%
# TODO: Implement after downloading IPEDS data
