# %% [markdown]
# # 02 — Cross Year Schema Analysis
#
# Compare column schemas across IPEDS survey years.

# %%
import polars as pl
from src.config import SURVEY_COMPONENTS, SURVEY_YEARS

print("Schema analysis notebook ready.")
