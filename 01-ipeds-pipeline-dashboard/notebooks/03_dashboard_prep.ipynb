# %% [markdown]
# # 03 — Dashboard Preparation
#
# Prepare the final combined dataset for Tableau and Power BI.

# %%
import polars as pl
from src.config import PROCESSED_DIR

print("Dashboard prep notebook ready.")
